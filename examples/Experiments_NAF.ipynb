# %%
import os
from trainer import Trainer
from algorithms.NAF.agent import NAFAgent

# %%
model_name = 'NAF'
dataset = 'DOW30'
reward = False
print_every = 1
#timestep = 10_000
#trading_cost = 0.0

timesteps = [100_000]
trading_costs = [0, 0.001, 0.01]

for timestep in timesteps:
    for trading_cost in trading_costs:
        if reward:
            strng = 'LogRets'
        else:
            strng = 'ShRt'

        path = f'Reward-{strng}_timestep-{timestep}_trading_cost-{trading_cost}'
        isExist = os.path.exists(path)
        if not isExist:
            os.makedirs(path) 

        name = f'{path}/{model_name}_{path}'

        trainer = Trainer('../data/DOW30.csv', 
                         experiment_name = name, 
                         timesteps = timestep, 
                         print_every = print_every,
                         episode_length = None,
                         returns = reward,
                         trading_cost_ratio = trading_cost ,
                         lookback_period = 64,
                         initial_investment = 1_000_000,
                         random_start_range = 20,
                         dsr_constant = 1e-4,
                         add_softmax = True)

        env = trainer.get_train_env()
        model = NAFAgent(env, device = 'cpu')
        returns = trainer.run(model)
# Out:
# Score at timestep 1838: 1.5883213771326352.
# Score at timestep 3673: 1.2517122298114483.
# Score at timestep 5523: 2.025027080863712.
# Score at timestep 7370: 1.952409276998871.
# Score at timestep 9217: 1.955954792569754.
# Score at timestep 11060: 2.059467337566732.
# Score at timestep 12901: 2.1636124645806496.
# Score at timestep 14732: 1.0889729864485154.
# Score at timestep 16564: 1.093842590066697.
# Score at timestep 18410: 1.9225439380162321.
# Score at timestep 20254: 2.0401757737350747.
# Score at timestep 22092: 1.604953083658589.
# Score at timestep 23941: 1.9105219531381696.
# Score at timestep 25785: 2.0450373895121037.
# Score at timestep 27628: 2.0476632463969633.
# Score at timestep 29464: 1.3743431124671481.
# Score at timestep 31297: 1.0846373462518457.
# Score at timestep 33142: 2.060195700780567.
# Score at timestep 34979: 1.559022153445256.
# Score at timestep 36821: 1.9688485886299079.
# Score at timestep 38662: 2.172473540186602.
# Score at timestep 40492: 1.1818475039523195.
# Score at timestep 42323: 1.101773321327396.
# Score at timestep 44157: 1.153318807467041.
# Score at timestep 45988: 1.0995461006905223.
# Score at timestep 47833: 2.0511294935098654.
# Score at timestep 49668: 1.2434799624972286.
# Score at timestep 51503: 1.2456984930144273.
# Score at timestep 53353: 2.020911396252101.
# Score at timestep 55185: 1.0653574511498758.
# Score at timestep 57032: 1.9460105882946666.
# Score at timestep 58865: 1.0741452367589.
# Score at timestep 60696: 1.0832359571911458.
# Score at timestep 62527: 1.099797765708651.
# Score at timestep 64358: 1.0854456673600383.
# Score at timestep 66194: 1.3962684454852017.
# Score at timestep 68037: 2.0768907068575397.
# Score at timestep 69887: 2.038783337982141.
# Score at timestep 71736: 1.902421432077392.
# Score at timestep 73577: 2.198211051512691.
# Score at timestep 75427: 2.0368909695641397.
# Score at timestep 77267: 2.0552981399640577.
# Score at timestep 79097: 1.1776546538553752.
# Score at timestep 80944: 1.9573580716016594.
# Score at timestep 82783: 1.7185276308536561.
# Score at timestep 84615: 1.080680706100964.
# Score at timestep 86463: 1.9029008729732668.
# Score at timestep 88313: 2.0167454490075.
# Score at timestep 90163: 2.0197310375624977.
# Score at timestep 92009: 1.936152635155996.
# Score at timestep 93854: 2.044156157455103.
# Score at timestep 95698: 2.0469528194681943.
# Score at timestep 97540: 1.981405453490008.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.19s/it]
# Score at timestep 1838: 1.5882905295442742.
# Score at timestep 3673: 1.2515851461826846.
# Score at timestep 5523: 2.024946451711441.
# Score at timestep 7370: 1.9523486768313743.
# Score at timestep 9217: 1.9559046536959481.
# Score at timestep 11060: 2.05920242153082.
# Score at timestep 12901: 2.163530234226592.
# Score at timestep 14732: 1.0888567668950266.
# Score at timestep 16564: 1.093535957380265.
# Score at timestep 18410: 1.9226836980573998.
# Score at timestep 20254: 2.0401577577475902.
# Score at timestep 22092: 1.6050056205534065.
# Score at timestep 23941: 1.9101585944656765.
# Score at timestep 25785: 2.0444707718170956.
# Score at timestep 27628: 2.047763012809772.
# Score at timestep 29464: 1.374522250532673.
# Score at timestep 31297: 1.0845415342352132.
# Score at timestep 33142: 2.059295497898628.
# Score at timestep 34979: 1.5588654737766603.
# Score at timestep 36821: 1.9697360509022728.
# Score at timestep 38662: 2.1724617388423098.
# Score at timestep 40492: 1.1820791285877452.
# Score at timestep 42323: 1.1015644444210948.
# Score at timestep 44157: 1.1530541099564058.
# Score at timestep 45988: 1.0994506753928348.
# Score at timestep 47833: 2.0504683469905123.
# Score at timestep 49668: 1.2440486294143165.
# Score at timestep 51503: 1.2443656746627763.
# Score at timestep 53353: 2.0206084320013376.
# Score at timestep 55185: 1.0653384918352293.
# Score at timestep 57032: 1.9460897602778187.
# Score at timestep 58865: 1.0743734295683751.
# Score at timestep 60696: 1.0836009467255296.
# Score at timestep 62527: 1.1005659119376499.
# Score at timestep 64358: 1.0855772311425325.
# Score at timestep 66194: 1.3963663329108036.
# Score at timestep 68037: 2.0768721367073306.
# Score at timestep 69887: 2.0387095839051415.
# Score at timestep 71736: 1.902839662794476.
# Score at timestep 73577: 2.1982398503835827.
# Score at timestep 75427: 2.036654373587085.
# Score at timestep 77267: 2.054755346450065.
# Score at timestep 79097: 1.1772166515148048.
# Score at timestep 80944: 1.9577023314019646.
# Score at timestep 82783: 1.7191164740723976.
# Score at timestep 84615: 1.0805396251848869.
# Score at timestep 86463: 1.9026308588107799.
# Score at timestep 88313: 2.0171787063361855.
# Score at timestep 90163: 2.018965066017191.
# Score at timestep 92009: 1.9361837083978184.
# Score at timestep 93854: 2.0437978433623893.
# Score at timestep 95698: 2.0455358692140226.
# Score at timestep 97540: 1.981465455479339.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.04s/it]
# Score at timestep 1838: 1.5880125492157942.
# Score at timestep 3673: 1.2504267263222597.
# Score at timestep 5523: 2.0239654363362463.
# Score at timestep 7370: 1.9522671292566947.
# Score at timestep 9217: 1.9556769692084446.
# Score at timestep 11060: 2.0587770919761548.
# Score at timestep 12901: 2.1625660410199203.
# Score at timestep 14732: 1.08941262732856.
# Score at timestep 16564: 1.0933239453964183.
# Score at timestep 18410: 1.9236028508354137.
# Score at timestep 20254: 2.0403781780424093.
# Score at timestep 22092: 1.6045012944981918.
# Score at timestep 23941: 1.9099111725568443.
# Score at timestep 25785: 2.0447827412729103.
# Score at timestep 27628: 2.0469900681992166.
# Score at timestep 29464: 1.3730378883624033.
# Score at timestep 31297: 1.0847052169531501.
# Score at timestep 33142: 2.0600372199393213.
# Score at timestep 34979: 1.5573370811182472.
# Score at timestep 36821: 1.970378883280686.
# Score at timestep 38662: 2.1716972254829927.
# Score at timestep 40492: 1.182931662299362.
# Score at timestep 42323: 1.1018795026310224.
# Score at timestep 44157: 1.152314188813509.
# Score at timestep 45988: 1.0997163718478322.
# Score at timestep 47833: 2.050856785143734.
# Score at timestep 49668: 1.242193319647203.
# Score at timestep 51503: 1.2441097931316103.
# Score at timestep 53353: 2.0194164348670385.
# Score at timestep 55185: 1.0650576666111684.
# Score at timestep 57032: 1.9462815360126529.
# Score at timestep 58865: 1.074299616946373.
# Score at timestep 60696: 1.083434953255641.
# Score at timestep 62527: 1.1003673906281461.
# Score at timestep 64358: 1.0846005161773256.
# Score at timestep 66194: 1.395417162377103.
# Score at timestep 68037: 2.0754398803077976.
# Score at timestep 69887: 2.0363103005033696.
# Score at timestep 71736: 1.9029283865092044.
# Score at timestep 73577: 2.196450364955253.
# Score at timestep 75427: 2.0354110698955608.
# Score at timestep 77267: 2.0527457826766735.
# Score at timestep 79097: 1.1780414977392566.
# Score at timestep 80944: 1.9570051151721246.
# Score at timestep 82783: 1.7178447822444878.
# Score at timestep 84615: 1.0795597688052572.
# Score at timestep 86463: 1.9037525229717231.
# Score at timestep 88313: 2.015899977060196.
# Score at timestep 90163: 2.0189905227276355.
# Score at timestep 92009: 1.9374043233575577.
# Score at timestep 93854: 2.0443471767495045.
# Score at timestep 95698: 2.045460066010051.
# Score at timestep 97540: 1.9838535237631203.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.03s/it]

# %%
from experiment import Experiment

# %%
trainer_kw = {'print_every': 10, 'test_runs': 100, 'add_softmax' : False} 
model_kw = {'device': 'cpu'}

exp = Experiment(trainer_kw, model_kw)
exp.run('TRPO')
# Out:
# Initial loss
# 	loss | mean : 1.0302 / std : 0.0933
# 1915
# loss | mean : 1.0341 / std : 0.1163
# 3830
# loss | mean : 0.9847 / std : 0.0932
# 5745
# loss | mean : 1.0272 / std : 0.1037
# 7660
# loss | mean : 1.0183 / std : 0.0746
# 9575
# loss | mean : 0.9848 / std : 0.0780
# 11490
# loss | mean : 1.0177 / std : 0.0938
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [02:25<00:00,  1.45s/it]
# Reward-LogRets_timestep-10000_trading_cost-0 : 0.3505455086518065
# Initial loss
# 	loss | mean : 0.9864 / std : 0.0939
# 1915
# loss | mean : 1.0134 / std : 0.0925
# 3830
# loss | mean : 0.9849 / std : 0.0853
# 5745
# loss | mean : 1.0206 / std : 0.0946
# 7660
# loss | mean : 1.0577 / std : 0.1036
# 9575
# loss | mean : 1.0998 / std : 0.0839
# 11490
# loss | mean : 1.0674 / std : 0.1055
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [02:33<00:00,  1.54s/it]
# ...

# %% [markdown]
# # NAF

# %%
trainer_kw = {'print_every': 10, 'test_runs': 100} 

exp = Experiment(trainer_kwargs = trainer_kw)
exp.run('NAF')
